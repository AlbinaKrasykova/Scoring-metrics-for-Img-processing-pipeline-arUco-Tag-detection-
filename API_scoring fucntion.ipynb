# %% [markdown]
# **API - Documentation of scoring function**

# %% [markdown]
# import the libraries

# %%
import math
import os
import re
import cv2

# %%
dictionary = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)
parameters = cv2.aruco.DetectorParameters 
detector = cv2.aruco.ArucoDetector(dictionary)

# %% [markdown]
# **Gather or download the excited metadata, and load it**
#
# *Metadata description*
#
# 5K images of arUco tags, 5 ids and 10 different conditions captured (angle, distance, light)

# %%
data_1 =  r'D:\AI research internship\opencv_scripts\a_70_d_4'
data_2 =  r'D:\AI research internship\opencv_scripts\a_70_d_10'
data_4  = r'D:\AI research internship\opencv_scripts\a_28_d_10'
data_5  = r'D:\AI research internship\opencv_scripts\a_5_d_4'
data_6  = r'D:\AI research internship\opencv_scripts\a_50_d_10'
data_7  = r'D:\AI research internship\opencv_scripts\a_50_d_4'
data_8 = r'D:\AI research internship\opencv_scripts\a_70_d_20'
data_9 = r'D:\AI research internship\opencv_scripts\a_50_d_20'
data_10 = r'D:\AI research internship\opencv_scripts\a_28_d_20'
data_11 = r'D:\AI research internship\opencv_scripts\a_5_d_20'

# %% [markdown]
# **Load and prepere the data:**
#
# 1. - clean_string function - checks if the data was labeled, correctly if not returns the correct formatting
#
# clean_string(string) - accept name of an image and if it's other then id and count (For example 3id_10count returns clean format - 3_10)
#
# 2. - load the large data in batches saves your gpu, and pc from a crash
#
# >load_images_in_batches(directory, batch_size, batch_index=0) - accepts param-1 path of the metadata, param-2 batch size or how much images do you want to have per batch, and  param-3 starting batch_index at 0 - batch_index=0

# %%
def clean_string(string):
        digits = re.findall(r'\d+', string)
        if len(digits) > 1:
            digits = digits[:-1]  
        cleaned_string = '_'.join(digits)
        count = len(digits)
        
        return count, cleaned_string

# %%
def load_images_in_batches(directory, batch_size, batch_index=0):
    # os - intereacting with the operating system
    # listdir - returns a list of all the files
    image_files = os.listdir(directory)
    total_images = len(image_files)
    #math.ceil() function is used to round up to the nearest integer value
    num_batches = math.ceil(total_images / batch_size)

    for i in range(num_batches):
        batch_index +=1
        start_index = i * batch_size
        end_index = min(start_index + batch_size, total_images)
        batch_files = image_files[start_index:end_index]
        
        batch_images = {}
        for file in batch_files:
            
            image_path = os.path.join(directory, file)
            image = cv2.imread(image_path)
            image_name = os.path.splitext(file)[0]  # Extract name without extension
            batch_images[image_name] = image
        print()
        print('Batch number: ', batch_index)
        print()
        
        yield batch_images

# %% [markdown]
# **Get an array with ids we expect to get**
#
# >get_original_id(image_dict)  - accepts param-1 which is an image_dictionary
#
# Example:
#
# for batch in load_images_in_batches(directory, batch_size):
#                         original_ids = get_original_id(batch)

# %%
def get_original_id(image_dict):
        arr = []

        for key in image_dict.keys():
            count, key = clean_string(key)
            #print('Count of ids is', count, 'the key is', key)
            pattern = r'^(\d{1,2})'  # Create the pattern based on the ID count

            for _ in range(1, count):
                pattern += r'_(\d{1,2})'

            digit_set = set()
            match = re.match(pattern, key)
            if match:
                for group in match.groups():
                    digit_set.add(int(group))
                arr.append(digit_set)
            else:
                print(f"Key '{key}' does not match the pattern.")
        print('Original ids')        
        print(arr)
        return arr

# %% [markdown]
# **Create an image processing pipeline, and collect the predicted ids to predcited ids array of sets**
# Each id or group of ids that were predicted are stored in sets, and each of these sets are stores in an array.

# %%
def img_p_ppln(image_dict):
            arr = []
            p_id_set = set()
            for ids, img in image_dict.items():
                transformation = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                transformation = cv2.bitwise_not(transformation)
                clahe = cv2.createCLAHE(clipLimit=4, tileGridSize=(16, 16))
                transformation = clahe.apply(transformation)

                transformation = cv2.GaussianBlur(transformation, (21, 21), 0)

                transformation = cv2.adaptiveThreshold(transformation, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 37, 1)

                _,transformation = cv2.threshold(transformation, 150, 255, cv2.THRESH_BINARY)  # Renamed 'transformation' to 'de
                _,ids,_ = detector.detectMarkers(transformation)   
                p_id_set = set()
                
                if ids is not None:
                    for inner_arr in ids:
                        for i in inner_arr:
                            p_id_set.add(i)
                        
                arr.append(p_id_set)
            print('F_2 predictions: ')    
            print(arr) 
            return arr

# %% [markdown]
# **Function that Classifies each of predcited id by the rate as TP, FP, FN, TN**
#
# >classify(original_ids, predicted_ids) - > needs 2 parameters, param-1 - original_ids, and param-2 predicted_ids.
#
# Output: Total of FP, FN, TP, TN rates, total score and total sum of all the images

# %%
def classify(original_ids, predicted_ids):
        TP = 0
        FP = 0
        FN = 0
        TN = 0
        FP = 0
        FP2=0
        scores = 0
        intersection = 0
        total = len(original_ids)
        for set_o, set_p in zip(original_ids, predicted_ids):
          #1 value and not empty cases part-1
          #if len(set_o)==1:
            #True positive 
            if set_o != set():
                intersection = set_o&set_p
                TP+=len(intersection)
                if len(intersection)>0:
                    scores += 1
              #false positive one {40}->{13}
                if set_o != set_p:
                    if set_p != set():
                        FP += 1
              # false negative {20}->set
                if set_p == set():
                    FN += 1
            #empty set_o part 2 
            if set_o == set():
               #True negative case set() -> set()
               if set_o == set_p:
                    TN += 1
                    scores += 1
                # set() - > {17}
               if set_o != set_p:
                    FP2 += 1
        #total_TP, total_FP, total_FN, true_negative, false_positive2, scores, total
        return TP, TN, FP, FN, FP2, scores, total

# %% [markdown]
# **function info - prints the detailed info on how img p ppln perfomed**

# %%
def info(TP, TN, FP, FN, FP2, scores, total):
        precision = 0
        recall = 0

        if TP + FP + FP2 != 0:
            precision = TP / (TP + FP + FP2)
        else:
            precision = 0

        if TP + FN != 0:
            recall = TP / (TP + FN)
        else:
            recall = 0

        print(f'Predicted: Score:{(scores/total)*100}% | TP:{TP}, FN:{FN}, TN:{TN}, FP1:{FP}, FP2:{FP2} | precision:{precision}, recall:{recall}')
        print(f'Out of {total} images, {TP} were predicted accurately')

# %% [markdown]
# **Score function**
# scores the ppln, and can take param-1 any customized img processing ppln but which return predidcted ids in sets of array format (Example: [{3,99},set(),{3}]), param-2 directory or a path, name_folder.

# %%
name = {
        data_1: 'a_70_d_4',
        data_2 : 'a_70_d_10',
        data_4: 'a_28_d_10',
        data_5: 'a_5_d_4',
        data_6: 'a_50_d_10',
        data_7: 'a_50_d_4',
        data_8: 'a_70_d_20',
        data_9: 'a_50_d_20',
        data_10 : 'a_28_d_20t',
        data_11: 'a_5_d_20'
    }
        
path = {
        data_1: 'Angle: 70, Distance: 4, Lighting: low day light at 5:48 PM',
        data_2 : 'Angle: 70, Distance: 10, Lighting: low day light at 7:50 PM',
        data_4: 'Angle: 28, Distance: 10, Lighting: low day light at 8:48 PM',
        data_5: 'Angle: 5, Distance: 4, Lighting: low day light at 3:58 PM',
        data_6: 'Angle: 50, Distance: 10, Lighting: bright artificial and day light at 7:53 ',
        data_7: 'Angle: 50, Distance: 4, Lighting: bright artificial light low evening light at 7:01 PM',
        data_8: 'Angle: 70, Distance: 20, Lighting: low day light at 7:41 PM',
        data_9: 'Angle: 50, Distance: 20, Lighting: bright artificial light at 9:32 PM',
        data_10 : 'Angle: 28, Distance: 20, Lighting: bright artificial light at 9:49 PM',
        data_11: 'Angle: 5, Distance: 20, Lighting: bright artificial light at 10:08 PM'
    }

# %%
def score(ppln, directory, folder_name):
                    batch_size = 150
                    for batch in load_images_in_batches(directory, batch_size):
                        original_ids = get_original_id(batch)
                        #print(original_ids)
                        predicted_ids = ppln(batch)
                       
                        #new_arr_predicted_ids = [int(x[0, 0]) if x is not None else None for x in predicted_ids]
                        #print(predicted_ids)
                        TP, TN, FP, FN, FP2, scores, total = classify(original_ids,predicted_ids)
                        info(TP, TN, FP, FN, FP2, scores, total)

# %%
values = path.values()
keys = path.keys()
def loop_print(values,keys):
   for value, key in zip(path.values(), path.keys()):
      folder_name = name[key]  # Get the corresponding folder name from the name dictionary
      print()
      print(f'Folder: {folder_name}')
      print()
      print('Conditions:', value)
      print()
      score(img_p_ppln, key, folder_name)

# %%
values = path.values()
keys = path.keys()
loop_print(values, keys)
'''
for value, key in zip(path.values(), path.keys()):
          folder_name = name[key]  # Get the corresponding folder name from the name dictionary
          print()
          print(f'Folder: {folder_name}')
          print()
          print('Conditions:', value)
          print()
          score(img_p_ppln, key, folder_name)
'''
# Out:
# Folder: a_70_d_4
#
# Conditions: Angle: 70, Distance: 4, Lighting: low day light at 5:48 PM
#
#
# Batch number:  1
#
# Original ids
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {40, 3}, set(), set(), set(), set(), set(), set(), set(), set(), {3}, set(), {3}, {3}, {3}, {3}, {3}, set(), set(), set(), {3}, {3}, {3}, set(), set(), set(), set(), {3}, {3}, {3}, set(), set()]
# Predicted: Score:8.666666666666668% | TP:13, FN:135, TN:0, FP1:3, FP2:0 | precision:0.8125, recall:0.08783783783783784
# Out of 150 images, 13 were predicted accurately
#
# Batch number:  2
#
# Original ids
# [{3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), {3}, set(), set(), set(), set(), set(), {3}, {3}, set(), set(), set(), {3}, {3}, set(), set(), {3}, set(), {3}, set(), {3}, set(), {3}, set(), {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, set(), {40}, set(), {40}, set(), set(), set(), set(), set(), set(), {40}, {40}, set(), {40}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {40}, set(), set(), set(), set(), set(), set(), set(), {40}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {40}, set(), set(), {40}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {40}, set(), {130}, set(), {40}, set(), {40}, set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:22.666666666666664% | TP:34, FN:115, TN:0, FP1:1, FP2:0 | precision:0.9714285714285714, recall:0.22818791946308725
# Out of 150 images, 34 were predicted accurately
#
# Batch number:  3
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {48}, set(), set(), {48}, set(), set(), {48}, set(), set(), set(), set(), {48}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {48}, set(), {48}, {48}, set(), set(), set(), set(), set(), {48}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:7.017543859649122% | TP:8, FN:106, TN:0, FP1:0, FP2:0 | precision:1.0, recall:0.07017543859649122
# Out of 114 images, 8 were predicted accurately
#
# Folder: a_70_d_10
#
# Conditions: Angle: 70, Distance: 10, Lighting: low day light at 7:50 PM
#
#
# Batch number:  1
#
# Original ids
# [{22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {120}, set(), set(), set(), set(), set(), {37}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {22}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {23}, set(), {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:2.0% | TP:3, FN:144, TN:0, FP1:3, FP2:0 | precision:0.5, recall:0.02040816326530612
# Out of 150 images, 3 were predicted accurately
#
# Batch number:  2
#
# Original ids
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3, 109}, {3}, {3}, {3}, {3}, {3}, {3}, {3, 163}, {3}, {3}, {3}, {3}, set(), set(), set(), set(), set(), set(), set(), set(), set(), {190}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}]
# Predicted: Score:54.0% | TP:81, FN:68, TN:0, FP1:3, FP2:0 | precision:0.9642857142857143, recall:0.5436241610738255
# Out of 150 images, 81 were predicted accurately
#
# Batch number:  3
#
# Original ids
# [{40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [{40, 190}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40, 17}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, set(), set(), {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, set(), set(), set(), set(), set(), set(), set(), {48}, set(), set(), set(), set(), set(), set(), set(), set(), set(), {48}, {48}, set(), {48}, set(), set(), set(), set(), set(), set(), set(), set(), {48}, set()]
# Predicted: Score:81.33333333333333% | TP:122, FN:28, TN:0, FP1:2, FP2:0 | precision:0.9838709677419355, recall:0.8133333333333334
# Out of 150 images, 122 were predicted accurately
#
# Batch number:  4
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, set(), {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, set(), {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, set(), {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, set(), set(), {48}, {48}, set(), set(), set(), set(), set(), set()]
# Predicted: Score:92.66666666666666% | TP:139, FN:11, TN:0, FP1:0, FP2:0 | precision:1.0, recall:0.9266666666666666
# Out of 150 images, 139 were predicted accurately
#
# Batch number:  5
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), {48}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {48}, set(), set(), set(), set(), set(), set(), set(), {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48, 209}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48, 190}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48, 17}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# Predicted: Score:86.0% | TP:129, FN:21, TN:0, FP1:3, FP2:0 | precision:0.9772727272727273, recall:0.86
# Out of 150 images, 129 were predicted accurately
#
# Batch number:  6
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48, 87}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, set(), {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# Predicted: Score:99.33333333333333% | TP:149, FN:1, TN:0, FP1:1, FP2:0 | precision:0.9933333333333333, recall:0.9933333333333333
# Out of 150 images, 149 were predicted accurately
#
# Batch number:  7
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# Predicted: Score:100.0% | TP:28, FN:0, TN:0, FP1:0, FP2:0 | precision:1.0, recall:1.0
# Out of 28 images, 28 were predicted accurately
#
# Folder: a_28_d_10
#
# Conditions: Angle: 28, Distance: 10, Lighting: low day light at 8:48 PM
#
#
# Batch number:  1
#
# Original ids
# [{22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {22}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {22}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {22}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# Predicted: Score:22.666666666666664% | TP:34, FN:116, TN:0, FP1:0, FP2:0 | precision:1.0, recall:0.22666666666666666
# Out of 150 images, 34 were predicted accurately
#
# Batch number:  2
#
# Original ids
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# F_2 predictions:
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {190, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {37, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {17, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# Predicted: Score:100.0% | TP:150, FN:0, TN:0, FP1:3, FP2:0 | precision:0.9803921568627451, recall:1.0
# Out of 150 images, 150 were predicted accurately
#
# Batch number:  3
#
# Original ids
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# F_2 predictions:
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {190, 23}, {23}, {23}, {17, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {17, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {17, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {17, 23}, {17, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {17, 23}, {23}, {23}, {17, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {17, 23}, {17, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {17, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# Predicted: Score:100.0% | TP:150, FN:0, TN:0, FP1:11, FP2:0 | precision:0.9316770186335404, recall:1.0
# Out of 150 images, 150 were predicted accurately
#
# Batch number:  4
#
# Original ids
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {40}, {40}, {40}, {40}, {40}, {40}, {40}]
# F_2 predictions:
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {190, 23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {40}, {40}, {40}, {40}, {40}, {40}, {40}]
# Predicted: Score:88.0% | TP:132, FN:18, TN:0, FP1:1, FP2:0 | precision:0.9924812030075187, recall:0.88
# Out of 150 images, 132 were predicted accurately
#
# Batch number:  5
#
# Original ids
# [{40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [{40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {190}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:67.33333333333333% | TP:101, FN:48, TN:0, FP1:1, FP2:0 | precision:0.9901960784313726, recall:0.6778523489932886
# Out of 150 images, 101 were predicted accurately
#
# Batch number:  6
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:0.0% | TP:0, FN:47, TN:0, FP1:0, FP2:0 | precision:0, recall:0.0
# Out of 47 images, 0 were predicted accurately
#
# Folder: a_5_d_4
#
# Conditions: Angle: 5, Distance: 4, Lighting: low day light at 3:58 PM
#
#
# Batch number:  1
#
# Original ids
# [{22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, {17}, {17}, set(), {17}, set(), set(), {17}, set(), {17, 23}, set(), {23}, set(), set(), set(), set(), set(), {23}, {23}, {23}, set(), set(), set(), {23}, {23}, {23}, set(), set(), set(), set(), set(), set(), set(), set(), {23}, set(), {17}, set(), set(), set(), set(), set(), set(), {23}, {23}, {23}, set(), set(), set(), {17, 23}, {23}, {17}, {17}, {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:10.0% | TP:15, FN:127, TN:0, FP1:10, FP2:0 | precision:0.6, recall:0.1056338028169014
# Out of 150 images, 15 were predicted accurately
#
# Batch number:  2
#
# Original ids
# [{3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {34}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {190}, set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, {17}, set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {190}, set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:0.0% | TP:0, FN:141, TN:0, FP1:9, FP2:0 | precision:0.0, recall:0.0
# Out of 150 images, 0 were predicted accurately
#
# Batch number:  3
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:0.0% | TP:0, FN:70, TN:0, FP1:0, FP2:0 | precision:0, recall:0.0
# Out of 70 images, 0 were predicted accurately
#
# Folder: a_50_d_10
#
# Conditions: Angle: 50, Distance: 10, Lighting: bright artificial and day light at 7:53
#
#
# Batch number:  1
#
# Original ids
# [{22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:0.0% | TP:0, FN:150, TN:0, FP1:0, FP2:0 | precision:0, recall:0.0
# Out of 150 images, 0 were predicted accurately
#
# Batch number:  2
#
# Original ids
# [{22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {22}, {22}, {22}, {22}, set(), set(), {22}, set(), {22}, {22}, {22}, {22}, {22}, set(), {22}, set(), {22}, set(), {22}, set(), {22}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {22}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {117}, set(), set(), {90}, set(), set(), set(), {242}, {17}, {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {242}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:10.0% | TP:15, FN:129, TN:0, FP1:6, FP2:0 | precision:0.7142857142857143, recall:0.10416666666666667
# Out of 150 images, 15 were predicted accurately
#
# Batch number:  3
#
# Original ids
# [{3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}]
# F_2 predictions:
# [set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {37}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {190}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:0.0% | TP:0, FN:147, TN:0, FP1:3, FP2:0 | precision:0.0, recall:0.0
# Out of 150 images, 0 were predicted accurately
#
# Batch number:  4
#
# Original ids
# [{40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {48}, {48}, {48}, {48}, {48}, {48}, {48}, set(), {48}, set(), set(), {48}, {48}, {48}, set(), {48}, {48}, {48}, {48, 127}, {48}, {48}, set(), {48}, {48}, {48}, {48}, {48}, {48}, {48, 127}, {48}, {48}, {48}, set(), {48}, set(), {127}, {48}, {48, 127}, {48}, {48, 127}, {48}, {48}, {48}, set(), {48}, {48, 127}, {48, 127}, {127}, {48}, set(), {48}, {48}, {48}, {48}, set(), {48}, {48}, set(), {48}, {48}, {48, 127}, {48}, {48}, {48}, {48}, set(), {48}, {48}, {48}, {127}, set(), set(), set(), set(), set(), set(), {48}, {48}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:38.0% | TP:57, FN:90, TN:0, FP1:10, FP2:0 | precision:0.8507462686567164, recall:0.3877551020408163
# Out of 150 images, 57 were predicted accurately
#
# Batch number:  5
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, set(), set(), {48}, set(), set(), {48}, {48}, {48}, set(), set(), set(), set(), set(), {48}, set(), {48}, set(), set(), {48}, {48}, set(), {48}, set(), {48}, {48}, set(), {48}, {48}, {48}, {127}, {48}, {48}, {48}, set(), {48}, {48}, set(), {48}, {48}, {48}, set(), {48}, {48}, {48}, set(), {48}, {48}, {48, 99}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# Predicted: Score:65.67164179104478% | TP:44, FN:22, TN:0, FP1:2, FP2:0 | precision:0.9565217391304348, recall:0.6666666666666666
# Out of 67 images, 44 were predicted accurately
#
# Folder: a_50_d_4
#
# Conditions: Angle: 50, Distance: 4, Lighting: bright artificial light low evening light at 7:01 PM
#
#
# Batch number:  1
#
# Original ids
# [{22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# F_2 predictions:
# [set(), set(), {22}, set(), {22}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {22}, set(), {22}, set(), {22}, set(), set(), set(), set(), set(), {112}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {22}, set(), set(), {22}, {22}, {22}, {22}, {22}, {22}, set(), {190}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {22}, set(), {22}, set(), set(), set(), set(), set(), {22}, {22}, set(), set(), {22}, {22}, set(), {22}, set(), set(), set(), {22}, {22}, {22}, {22}, set(), set(), set(), set(), {23}, set(), set(), set(), {23}, set(), {23}, {23}, {23}, set(), {23}, {23}, set(), set(), set(), set(), set(), set(), set(), {23}, {23}, {23}, {23}, {23}, {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {23}, set(), set(), set(), set(), set(), {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:25.333333333333336% | TP:38, FN:110, TN:0, FP1:2, FP2:0 | precision:0.95, recall:0.25675675675675674
# Out of 150 images, 38 were predicted accurately
#
# Batch number:  2
#
# Original ids
# ...
# F_2 predictions:
# [{3}, set(), set(), {3}, {3}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:2.0% | TP:3, FN:147, TN:0, FP1:0, FP2:0 | precision:1.0, recall:0.02
# Out of 150 images, 3 were predicted accurately
#
# Batch number:  5
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:0.0% | TP:0, FN:42, TN:0, FP1:0, FP2:0 | precision:0, recall:0.0
# Out of 42 images, 0 were predicted accurately
#
# Folder: a_28_d_20t
#
# Conditions: Angle: 28, Distance: 20, Lighting: bright artificial light at 9:49 PM
#
#
# Batch number:  1
#
# Original ids
# [{22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), {17}, {17}, set(), {37}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {145}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {23}, set(), set(), set(), set(), set(), set(), {23}, set(), set(), {23}, set(), set(), {23}, {23}, {23}, set(), set(), set(), set(), set(), {145}, set(), set(), set(), set(), set(), set(), set(), set(), set(), {190}, set(), {23}, set(), set(), {23}, set(), set(), set()]
# Predicted: Score:5.333333333333334% | TP:8, FN:133, TN:0, FP1:9, FP2:0 | precision:0.47058823529411764, recall:0.05673758865248227
# Out of 150 images, 8 were predicted accurately
#
# Batch number:  2
#
# Original ids
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [{23}, set(), set(), set(), set(), set(), set(), {23}, {23}, set(), set(), set(), set(), set(), set(), {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {3}, set(), set(), {3}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {3}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), {3}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {3}, {3}, set(), set(), set(), set(), {3}, set(), set(), set(), {3}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {40}, set(), set(), set(), set(), set(), {190}, {40}, set(), set(), set(), set(), set(), set(), set(), {37}, set(), set(), set(), set(), set()]
# Predicted: Score:9.333333333333334% | TP:14, FN:133, TN:0, FP1:3, FP2:0 | precision:0.8235294117647058, recall:0.09523809523809523
# Out of 150 images, 14 were predicted accurately
#
# Batch number:  3
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:0.0% | TP:0, FN:85, TN:0, FP1:1, FP2:0 | precision:0.0, recall:0.0
# Out of 86 images, 0 were predicted accurately
#
# Folder: a_5_d_20
#
# Conditions: Angle: 5, Distance: 20, Lighting: bright artificial light at 10:08 PM
#
#
# Batch number:  1
#
# Original ids
# [{22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {22}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {130}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {233}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {23}, {23}, set(), set(), {23}, {23}, set(), set(), set(), set(), set(), set(), set(), {226, 23}, set(), set(), set(), set(), {17, 23}, {23}, {17}, set(), {17}, set(), {17}, {23}, {23}, {23}, {23}, {23}, set()]
# Predicted: Score:8.0% | TP:12, FN:132, TN:0, FP1:8, FP2:0 | precision:0.6, recall:0.08333333333333333
# Out of 150 images, 12 were predicted accurately
#
# Batch number:  2
#
# Original ids
# [{23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {23}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}]
# F_2 predictions:
# [{23}, {23}, {23}, set(), set(), {23}, {17, 23}, {23}, {17}, {17, 23}, {17, 23}, {17, 23}, {17}, {23}, {226, 23}, set(), set(), set(), set(), {23}, set(), set(), set(), set(), set(), set(), {23}, set(), set(), set(), set(), {23}, set(), set(), set(), {23}, {23}, set(), {23}, set(), {23}, set(), {23}, set(), set(), {23}, set(), set(), set(), set(), {23}, {23}, set(), {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {23}, {23}, {23}, set(), {23}, {23}, set(), set(), set(), set(), set(), {23}, {23}, {23}, {23}, set(), set(), set(), set(), {23}, set(), set(), set(), {23}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:22.666666666666664% | TP:34, FN:114, TN:0, FP1:7, FP2:0 | precision:0.8292682926829268, recall:0.22972972972972974
# Out of 150 images, 34 were predicted accurately
#
# Batch number:  3
#
# Original ids
# [{3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {3}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {40}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {190}, set(), set(), set(), set(), set(), set(), set(), set(), set(), {40}, set(), set(), set(), set(), {40}, set(), set(), set(), {40}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {40}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {40}, set(), set(), {40}, set(), set(), {40}, set(), set(), set(), {12}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {40}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {145}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:5.333333333333334% | TP:8, FN:139, TN:0, FP1:3, FP2:0 | precision:0.7272727272727273, recall:0.05442176870748299
# Out of 150 images, 8 were predicted accurately
#
# Batch number:  4
#
# Original ids
# [{48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}, {48}]
# F_2 predictions:
# [set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {17}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), set()]
# Predicted: Score:0.0% | TP:0, FN:80, TN:0, FP1:2, FP2:0 | precision:0.0, recall:0.0
# Out of 82 images, 0 were predicted accurately
# "\nfor value, key in zip(path.values(), path.keys()):\n          folder_name = name[key]  # Get the corresponding folder name from the name dictionary\n          print()\n          print(f'Folder: {folder_name}')\n          print()\n          print('Conditions:', value)\n          print()\n          score(img_p_ppln, key, folder_name)\n"
